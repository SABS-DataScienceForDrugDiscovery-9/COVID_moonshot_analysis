# %%
from IPython.display import Image

# %% [markdown]
# <font size = "200"> Data Science for Drug Discovery </font>
# ### Marco Corrao, Nicholas Fan and Katherine Shepherd

# %% [markdown]
# # What did we try?
# ### - Used the fingerprints
# ### 1. Looked at the distribution of fingerprints
# ### 2. Looked at the distribution of affinity
# ### 3. Data cleaning
# ### 4. Machine Learning
# ### - regression and classification
# ### - random forests and neural networks

# %% [markdown]
# # Fingerprints - clustering

# %%
# Output of clustering

Image("./clusterplot1.png")

# %% [markdown]
# # Distribution of affinity values

# %%
# graph of affinity values and say about lots at 99 so cut out these for regression

# %% [markdown]
# # Data Cleaning
# ### - 0 variance
# ### - correlation >95%

# %% [markdown]
# # Regression

# %% [markdown]
# # Regression - Random forest

# %% [markdown]
# # Regression - Neural Network

# %% [markdown]
# # Classification

# %% [markdown]
# # Classification - Random forest

# %% [markdown]
# # Classification - Neural Network

# %% [markdown]
# # Extensions/ what we might try if we had more time

# %% [markdown]
# # Questions
